# %%
import numpy as np
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# %%
import pandas as pd

# Load the data
regular_season = pd.read_csv("Consolidated Regular Season Data.csv")
playoffs = pd.read_csv("Consolidated Playoffs - Sheet1.csv")

# Remove asterisks from the team names in the regular season data
regular_season['Team'] = regular_season['Team'].str.replace('*', '', regex=False)

# Ensure data types are consistent for merging
playoffs['Year'] = playoffs['Year'].astype(int)
regular_season['Season (end)'] = regular_season['Season (end)'].astype(int)

# %%
# Merge regular season data with playoffs data for losers
merged = pd.merge(regular_season, playoffs, left_on=['Season (end)', 'Team'], right_on=['Year', 'Loser'], how='left')
merged['Lost To'] = merged['Winner']
merged['Year'] = merged['Season (end)']
merged['Round made it to'] = merged['Playoff Round']
merged.drop(columns=['Season (end)', 'Playoff Round', 'Winner', 'Loser'], inplace=True)

merged
# Out:
#      Rk                    Team   Age   W   L  PW  PL    MOV   SOS   SRS  ...  \
# 0     1              Miami Heat  29.0  58  24  61  21   7.46 -0.71  6.76  ...
# 1     2           Chicago Bulls  26.4  62  20  61  21   7.32 -0.79  6.53  ...
# 2     3      Los Angeles Lakers  30.2  57  25  58  24   6.11 -0.10  6.01  ...
# 3     4       San Antonio Spurs  28.8  61  21  56  26   5.71  0.16  5.86  ...
# 4     5          Boston Celtics  29.5  56  26  57  25   5.37 -0.54  4.83  ...
# ..   ..                     ...   ...  ..  ..  ..  ..    ...   ...   ...  ...
# 385  26  Portland Trail Blazers  25.1  33  49  31  51  -4.01  0.05 -3.96  ...
# 386  27       Charlotte Hornets  25.3  27  55  26  56  -6.24  0.35 -5.89  ...
# 387  28         Houston Rockets  22.1  22  60  23  59  -7.85  0.24 -7.62  ...
# 388  29         Detroit Pistons  24.1  17  65  22  60  -8.22  0.49 -7.73  ...
# 389  30       San Antonio Spurs  23.9  22  60  19  63 -10.04  0.22 -9.82  ...
#
#      TOV%.1  DRB%  FT/FGA.1  Successful                   Arena  Attend.  \
# 0      12.6  75.5     0.223           1  AmericanAirlines Arena  810,930
# 1      13.6  76.2     0.222           1           United Center  893,462
# 2      12.8  72.3     0.181           0          STAPLES Center  778,877
# 3      12.6  74.6     0.190           0             AT&T Center  750,879
# 4      14.8  74.7     0.235           0               TD Garden  763,584
# ..      ...   ...       ...         ...                     ...      ...
# 385    12.1  74.9     0.217           0             Moda Center  767,374
# 386    12.5  75.5     0.211           0         Spectrum Center  702,052
# 387    11.8  75.8     0.218           0           Toyota Center  668,865
# 388    11.9  74.0     0.231           0    Little Caesars Arena  759,715
# 389    12.0  74.9     0.201           0             AT&T Center  694,434
#
#      Attend./G  Year            Lost To                Round made it to
# 0       19,779  2011   Dallas Mavericks                          Finals
# 1       21,792  2011         Miami Heat       Eastern Conference Finals
# 2       18,997  2011   Dallas Mavericks   Western Conference Semifinals
# 3       18,314  2011  Memphis Grizzlies  Western Conference First Round
# 4       18,624  2011         Miami Heat   Eastern Conference Semifinals
# ..         ...   ...                ...                             ...
# 385     18,716  2023                NaN                             NaN
# 386     17,123  2023                NaN                             NaN
# 387     16,314  2023                NaN                             NaN
# 388     18,596  2023                NaN                             NaN
# 389     15,508  2023                NaN                             NaN
#
# [390 rows x 33 columns]

# %%
# For winners, especially for identifying NBA Champions
winners = playoffs[playoffs['Playoff Round'] == 'Finals'][['Winner', 'Year']]
winners['Round made it to'] = 'NBA Champion'
winners.rename(columns={'Winner': 'Team'}, inplace=True)

winners
# Out:
#                       Team  Year Round made it to
# 0           Denver Nuggets  2023     NBA Champion
# 15   Golden State Warriors  2022     NBA Champion
# 30         Milwaukee Bucks  2021     NBA Champion
# 45      Los Angeles Lakers  2020     NBA Champion
# 60         Toronto Raptors  2019     NBA Champion
# 75   Golden State Warriors  2018     NBA Champion
# 90   Golden State Warriors  2017     NBA Champion
# 105    Cleveland Cavaliers  2016     NBA Champion
# 120  Golden State Warriors  2015     NBA Champion
# 135      San Antonio Spurs  2014     NBA Champion
# 150             Miami Heat  2013     NBA Champion
# 165             Miami Heat  2012     NBA Champion
# 180       Dallas Mavericks  2011     NBA Champion

# %%
merged.set_index(['Team', 'Year'], inplace=True)
winners.set_index(['Team', 'Year'], inplace=True)

# Update 'Round made it to' for matching index entries in 'merged' using 'winners'
merged.loc[merged.index.isin(winners.index), 'Round made it to'] = 'NBA Champion'

# Reset the index to revert back to the standard dataframe format
merged.reset_index(inplace=True)

merged["Round made it to"] = merged["Round made it to"].str.replace('Western ', '', regex=False)
merged["Round made it to"] = merged["Round made it to"].str.replace('Eastern ', '', regex=False)

# Now, the 'merged' dataframe will reflect 'NBA Champion' in the 'Round made it to' column for the winners
merged.to_csv('NBA_Total_Season_Data.csv', index=False)

merged[merged["Round made it to"] == "NBA Champion"]
# Out:
#                       Team  Year  Rk   Age   W   L  PW  PL    MOV   SOS  ...  \
# 7         Dallas Mavericks  2011   8  30.9  57  25  53  29   4.23  0.18  ...
# 33              Miami Heat  2012   4  28.3  46  20  47  19   5.98 -0.27  ...
# 61              Miami Heat  2013   2  30.3  66  16  62  20   7.87 -0.84  ...
# 90       San Antonio Spurs  2014   1  28.9  62  20  61  21   7.72  0.28  ...
# 120  Golden State Warriors  2015   1  26.6  67  15  65  17  10.10 -0.09  ...
# 153    Cleveland Cavaliers  2016   4  28.1  57  25  57  25   6.00 -0.55  ...
# 180  Golden State Warriors  2017   1  28.2  67  15  67  15  11.63 -0.28  ...
# 212  Golden State Warriors  2018   3  28.8  58  24  56  26   5.98 -0.19  ...
# 242        Toronto Raptors  2019   3  27.3  58  24  56  26   6.09 -0.60  ...
# 274     Los Angeles Lakers  2020   5  29.5  52  19  48  23   5.79  0.49  ...
# 303        Milwaukee Bucks  2021   4  28.1  46  26  48  24   5.89 -0.32  ...
# 334  Golden State Warriors  2022   5  27.6  53  29  55  27   5.54 -0.02  ...
# 365         Denver Nuggets  2023   6  26.6  53  29  49  33   3.33 -0.29  ...
#
#      eFG%.1  TOV%.1  DRB%  FT/FGA.1  Successful                     Arena  \
# 7     0.488    13.0  74.8     0.206           1  American Airlines Center
# 33    0.479    15.8  73.9     0.200           1    AmericanAirlines Arena
# 61    0.487    14.8  73.0     0.200           1    AmericanAirlines Arena
# 90    0.482    12.8  76.4     0.184           1               AT&T Center
# 120   0.470    14.3  74.5     0.217           1              Oracle Arena
# 153   0.496    12.6  78.5     0.205           1       Quicken Loans Arena
# 180   0.486    13.5  74.9     0.198           1              Oracle Arena
# 212   0.504    12.6  76.3     0.186           1              Oracle Arena
# 242   0.509    13.1  77.1     0.190           1          Scotiabank Arena
# 274   0.515    14.1  78.8     0.205           1            STAPLES Center
# 303   0.536    11.5  79.7     0.157           1              Fiserv Forum
# 334   0.509    13.0  78.7     0.201           1              Chase Center
# 365   0.543    12.2  76.4     0.201           1                Ball Arena
#
#      Attend.  Attend./G  Lost To  Round made it to
# 7    824,162     20,102      NaN      NBA Champion
# 33   657,855     19,935      NaN      NBA Champion
# 61   819,290     19,983      NaN      NBA Champion
# 90   755,031     18,415      NaN      NBA Champion
# 120  803,436     19,596      NaN      NBA Champion
# 153  843,042     20,562      NaN      NBA Champion
# 180  803,436     19,596      NaN      NBA Champion
# 212  803,436     19,596      NaN      NBA Champion
# 242  812,822     19,825      NaN      NBA Champion
# 274  588,907     18,997      NaN      NBA Champion
# 303   64,780      1,799      NaN      NBA Champion
# 334  740,624     18,064      NaN      NBA Champion
# 365  788,635     19,235      NaN      NBA Champion
#
# [13 rows x 33 columns]

# %%
merged
# Out:
#                        Team  Year  Rk   Age   W   L  PW  PL    MOV   SOS  ...  \
# 0                Miami Heat  2011   1  29.0  58  24  61  21   7.46 -0.71  ...
# 1             Chicago Bulls  2011   2  26.4  62  20  61  21   7.32 -0.79  ...
# 2        Los Angeles Lakers  2011   3  30.2  57  25  58  24   6.11 -0.10  ...
# 3         San Antonio Spurs  2011   4  28.8  61  21  56  26   5.71  0.16  ...
# 4            Boston Celtics  2011   5  29.5  56  26  57  25   5.37 -0.54  ...
# ..                      ...   ...  ..   ...  ..  ..  ..  ..    ...   ...  ...
# 385  Portland Trail Blazers  2023  26  25.1  33  49  31  51  -4.01  0.05  ...
# 386       Charlotte Hornets  2023  27  25.3  27  55  26  56  -6.24  0.35  ...
# 387         Houston Rockets  2023  28  22.1  22  60  23  59  -7.85  0.24  ...
# 388         Detroit Pistons  2023  29  24.1  17  65  22  60  -8.22  0.49  ...
# 389       San Antonio Spurs  2023  30  23.9  22  60  19  63 -10.04  0.22  ...
#
#      eFG%.1  TOV%.1  DRB%  FT/FGA.1  Successful                   Arena  \
# 0     0.475    12.6  75.5     0.223           1  AmericanAirlines Arena
# 1     0.463    13.6  76.2     0.222           1           United Center
# 2     0.477    12.8  72.3     0.181           0          STAPLES Center
# 3     0.491    12.6  74.6     0.190           0             AT&T Center
# 4     0.469    14.8  74.7     0.235           0               TD Garden
# ..      ...     ...   ...       ...         ...                     ...
# 385   0.563    12.1  74.9     0.217           0             Moda Center
# 386   0.544    12.5  75.5     0.211           0         Spectrum Center
# 387   0.564    11.8  75.8     0.218           0           Toyota Center
# 388   0.557    11.9  74.0     0.231           0    Little Caesars Arena
# 389   0.576    12.0  74.9     0.201           0             AT&T Center
#
#      Attend.  Attend./G            Lost To        Round made it to
# 0    810,930     19,779   Dallas Mavericks                  Finals
# 1    893,462     21,792         Miami Heat       Conference Finals
# 2    778,877     18,997   Dallas Mavericks   Conference Semifinals
# 3    750,879     18,314  Memphis Grizzlies  Conference First Round
# 4    763,584     18,624         Miami Heat   Conference Semifinals
# ..       ...        ...                ...                     ...
# 385  767,374     18,716                NaN                     NaN
# 386  702,052     17,123                NaN                     NaN
# 387  668,865     16,314                NaN                     NaN
# 388  759,715     18,596                NaN                     NaN
# 389  694,434     15,508                NaN                     NaN
#
# [390 rows x 33 columns]

# %%
lost_to_data = merged.copy()
lost_to_data.rename(columns={col: f'Lost to {col}' for col in merged.columns if col not in ['Team', 'Year']}, inplace=True)

final_merged = pd.merge(merged, lost_to_data, left_on=['Lost To', 'Year'], right_on=['Team', 'Year'], how='left')

print(final_merged.head())
# Out:
#                Team_x  Year  Rk   Age   W   L  PW  PL   MOV   SOS  ...  \
# 0          Miami Heat  2011   1  29.0  58  24  61  21  7.46 -0.71  ...
# 1       Chicago Bulls  2011   2  26.4  62  20  61  21  7.32 -0.79  ...
# 2  Los Angeles Lakers  2011   3  30.2  57  25  58  24  6.11 -0.10  ...
# 3   San Antonio Spurs  2011   4  28.8  61  21  56  26  5.71  0.16  ...
# 4      Boston Celtics  2011   5  29.5  56  26  57  25  5.37 -0.54  ...
#
#    Lost to eFG%.1  Lost to TOV%.1  Lost to DRB%  Lost to FT/FGA.1  \
# 0           0.488            13.0          74.8             0.206
# 1           0.475            12.6          75.5             0.223
# 2           0.488            13.0          74.8             0.206
# 3           0.502            15.7          72.5             0.228
# 4           0.475            12.6          75.5             0.223
#
#    Lost to Successful             Lost to Arena  Lost to Attend.  \
# 0                 1.0  American Airlines Center          824,162
# 1                 1.0    AmericanAirlines Arena          810,930
# 2                 1.0  American Airlines Center          824,162
# 3                 0.0               FedEx Forum          600,687
# 4                 1.0    AmericanAirlines Arena          810,930
#
#    Lost to Attend./G        Lost to Lost To  Lost to Round made it to
# 0             20,102                    NaN              NBA Champion
# 1             19,779       Dallas Mavericks                    Finals
# 2             20,102                    NaN              NBA Champion
# 3             14,651  Oklahoma City Thunder     Conference Semifinals
# 4             19,779       Dallas Mavericks                    Finals
#
# [5 rows x 65 columns]
